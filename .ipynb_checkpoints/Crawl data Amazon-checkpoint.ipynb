# %% [markdown]
# ## Crawl a page

# %%
import pandas as pd
import re
import datetime
from pandas import DataFrame
import undetected_chromedriver as uc
from time import sleep
from selenium.common import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import ElementNotInteractableException
import urllib.request
import os
from dotenv import load_dotenv

# %%
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920x1080")
driver = uc.Chrome(options=options)

# %%
driver.get('https://www.amazon.com/')

# %% [markdown]
# ### Captcha

# %%
from PIL import Image
from pytesseract import pytesseract

# %%
captcha_image = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
    (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-row.a-spacing-large > div > div > div.a-row.a-text-center > img")))
image = captcha_image.get_attribute('src')
filename = datetime.datetime.now()
image_path = 'D:\CrawlDataAmazon\\'
folder_path = os.path.join(os.path.dirname(image_path), "data")
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
urllib.request.urlretrieve(image, os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S"))))

# %%
if os.path.exists(folder_path):
    files = os.listdir(folder_path)
    if len(files) > 1:
        files.sort(key=lambda x: os.path.getmtime(os.path.join(folder_path, x)), reverse=True)
        for file in files[1:]:
            file_path = os.path.join(folder_path, file)
            os.remove(file_path)
    print("List images:")
    for file in os.listdir(folder_path):
        print(file)
else:
    print("Folder not found.")

# %%
path_to_tesseract = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
path_to_image = os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S")))
pytesseract.tesseract_cmd = path_to_tesseract
img = Image.open(path_to_image)

#Extract text from image
text = pytesseract.image_to_string(img)
print(text)

# %%
captcha = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
    (By.CSS_SELECTOR, "#captchacharacters")))
captcha.send_keys(text)
sleep(2)

# %%
submit = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
    (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-section.a-spacing-extra-large > div > span > span > button")))
submit.click()

# %% [markdown]
# ### Crawl data

# %%
search_box = driver.find_element(By.ID, 'twotabsearchtextbox')
search_box.clear()

# %%
# input = "gaming keyboard"

# %%
keyword = input('What name do you want to crawl ?')
# Out:
# What name do you want to crawl ?gaming keyboard

# %%
search_box.send_keys(keyword)
search_button = driver.find_element(By.ID, 'nav-search-submit-button')
search_button.click()
driver.implicitly_wait(5)

# %%
items = WebDriverWait(driver,10).until(EC.presence_of_all_elements_located((By.XPATH, '//div[contains(@class, "s-result-item s-asin")]')))

# %%
product_name = []
product_code = []
product_price = []
product_ratings = []
product_ratings_num = []
product_link = []

# %%
for item in items:
    try:
        name = item.find_element(By.XPATH, './/span[@class="a-size-medium a-color-base a-text-normal"]')
        product_name.append(name.text)
    except:
        product_name.append("")
    
    try:
        data_code = item.get_attribute("data-asin")
        product_code.append(data_code)
    except:
        product_code.append("")
    
    # find price
    whole_price = item.find_elements(By.XPATH, './/span[@class="a-price-whole"]')
    fraction_price = item.find_elements(By.XPATH, './/span[@class="a-price-fraction"]')
    
    if whole_price != [] and fraction_price != []:
        price = '.'.join([whole_price[0].text, fraction_price[0].text])
    else:
        price = 0
    product_price.append(price)

    # find ratings box
    ratings_box = item.find_elements(By.XPATH, './/div[@class="a-row a-size-small"]/span')

    # find ratings and ratings_num
    if ratings_box != []:
        ratings = ratings_box[0].get_attribute('aria-label')
        ratings_num = ratings_box[1].get_attribute('aria-label')
    else:
        ratings, ratings_num = 0, 0
    
    product_ratings.append(ratings)
    product_ratings_num.append(str(ratings_num))
    
    # find link
    link = item.find_element(By.XPATH, './/a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]').get_attribute("href")
    product_link.append(link)

# %%
product_name
# Out:
# ['ASUS ROG Azoth 75% Wireless DIY Custom Gaming Keyboard, OLED Display, Three-Layer Dampening, Hot-Swappable ROG NX Red Switches & Keyboard Stabilizers, PBT Keycaps, RGB-Black',
#  'SteelSeries Apex 7 TKL Compact Mechanical Gaming Keyboard – OLED Smart Display – USB Passthrough and Media Controls – Linear and Quiet – RGB Backlit (Red Switch)',
#  'SteelSeries Apex 3 RGB Gaming Keyboard – 10-Zone RGB Illumination – IP32 Water Resistant – Premium Magnetic Wrist Rest (Whisper Quiet Gaming Switch)',
#  'Razer Ornata V3 X Gaming Keyboard: Low-Profile Keys - Silent Membrane Switches - Spill Resistant - Chroma RGB Lighting - Ergonomic Wrist Rest - Classic Black',
#  'Logitech G PRO Mechanical Gaming Keyboard, Ultra Portable Tenkeyless Design, Detachable Micro USB Cable, 16.8 Million Color LIGHTSYNC RGB Backlit Keys',
#  'Corsair K55 PRO LITE RGB Wired Membrane Gaming Keyboard (5-Zone Dynamic RGB Backlighting, Six Macro Keys with Stream Deck Integration, IP42 Dust and Spill Resistant, Dedicated Media Keys) Black',
#  'Razer BlackWidow V4 Pro Wired Mechanical Gaming Keyboard: Yellow Mechanical Switches - Linear & Silent - Doubleshot ABS Keycaps - Command Dial - Programmable Macros - Chroma RGB - Magnetic Wrist Rest',
#  'Razer DeathStalker V2 Pro Wireless Gaming Keyboard: Low-Profile Optical Switches - Clicky Purple - HyperSpeed Wireless & Bluetooth 5.0-40 Hr Battery - Ultra-Durable Coated Keycaps - RGB - White',
#  'Corsair K70 RGB PRO Mechanical Gaming Keyboard - Cherry MX Brown Keyswitches - 8,000Hz Hyper-Polling - Durable PBT Double-Shot Keycaps - Magnetic Soft-Touch Palm Rest - Black (QWERTY - NA Layout)',
#  'Corsair K70 PRO RGB Optical-USB-C Mechanical Gaming Keyboard - OPX Linear Switches, PBT Double-Shot Keycaps, 8,000Hz Hyper-Polling, Magnetic Soft-Touch Palm Rest - NA Layout, QWERTY - Black',
#  'ROCCAT Magma Mini - 60% RGB Gaming Keyboard with 5 Programmable Lighting Zones, Membrane Key switches, Programmable Function Layers, Anti-Ghosting, & Spill Resistance - Black',
#  'SteelSeries Apex 7 Mechanical Gaming Keyboard – OLED Smart Display – USB Passthrough and Media Controls – Linear , Quiet – RGB Backlit (Red Switch)',
#  'Logitech G610 Orion Red Backlit Mechanical Gaming Keyboard',
#  'Logitech G815 LIGHTSYNC RGB Mechanical Gaming Keyboard with Low Profile GL Tactile Key Switch, 5 programmable G-Keys,USB Passthrough, Dedicated Media Control, Black and White colorways',
#  'Razer BlackWidow V3 Mechanical Gaming Keyboard: Green Mechanical Switches - Tactile & Clicky - Chroma RGB Lighting - Compact Form Factor - Programmable Macro Functionality, Classic Black',
#  'Ractous RTK61BP 60% Wireless Mechanical Gaming Keyboard,RGB Blacklit PBT Sublimation Keycaps 61keys Bluetooth5.1/Wried Gaming Keyboard for PC/Mac Gamers,Hot-Swap Gateron Optical Red Switch-Black',
#  "New SteelSeries Apex Pro TKL 2023 Ed.- World's Fastest Mechanical Gaming Keyboard - Adjustable Actuation - Esports Tenkeyless - OLED Screen - RGB - PBT Keycaps - USB-C",
#  'SteelSeries Apex 7 Mechanical Gaming Keyboard – OLED Smart Display – USB Passthrough and Media Controls – Linear , Quiet – RGB Backlit (Red Switch)',
#  'ASUS ROG Azoth 75% Wireless DIY Custom Gaming Keyboard, OLED Display, Three-Layer Dampening, Hot-Swappable ROG NX Red Switches & Keyboard Stabilizers, PBT Keycaps, RGB-Black',
#  'HyperX Alloy Origins 60 - Mechanical Gaming Keyboard, Ultra Compact 60% Form Factor, Double Shot PBT Keycaps, RGB LED Backlit, NGENUITY Software Compatible - Linear HyperX Red Switch',
#  'ROCCAT Vulcan 121 AIMO Linear Mechanical Titan Switch Full-size PC Gaming Keyboard with Per-key AIMO RGB Lighting, Anodized Aluminum Top Plate and Detachable Palm Rest – Black',
#  'Razer Ornata V3 Gaming Keyboard: Low-Profile Keys - Mecha-Membrane Switches - UV-Coated Keycaps - Backlit Media Keys - 10-Zone RGB Lighting - Spill-Resistant - Magnetic Wrist Wrest - Classic Black']

# %%
product_asin
# Out:
# ['B0BSKX8W3B',
#  'B07TGQ7CNF',
#  'B07ZGDPT4M',
#  'B09X6GJ691',
#  'B09ZVLBP4M',
#  'B0BM2YKK7F',
#  'B09NMM4FY6',
#  'B07SWNSXQN',
#  'B08FQPLCNC',
#  'B0B9RLFYHW',
#  'B09CPV6T4C',
#  'B07SWNSXQN',
#  'B07QQB9VCV',
#  'B01CDYB8AG',
#  'B085TD1TV2',
#  'B0BV4BC7LV',
#  'B0B16JFF54',
#  'B0BSKX8W3B',
#  'B08LX76NKR',
#  'B08TZVGNZJ',
#  'B0BF64DN6H',
#  'B07YNHBVGQ',
#  'B0BSKX8W3B',
#  'B0BSKX8W3B',
#  'B07TGQ7CNF',
#  'B07ZGDPT4M',
#  'B09X6GJ691',
#  'B09ZVLBP4M',
#  'B0BM2YKK7F',
#  'B09NMM4FY6',
#  'B07SWNSXQN',
#  'B08FQPLCNC',
#  'B0B9RLFYHW',
#  'B09CPV6T4C',
#  'B07SWNSXQN',
#  'B07QQB9VCV',
#  'B01CDYB8AG',
#  'B085TD1TV2',
#  'B0BV4BC7LV',
#  'B0B16JFF54',
#  'B0BSKX8W3B',
#  'B08LX76NKR',
#  'B08TZVGNZJ',
#  'B0BF64DN6H',
#  'B07YNHBVGQ']

# %%
product_link
# Out:
# ['https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozNjczNzg4NjU4MzU0ODU5OjE2ODg5NjQyMDA6c3BfYXRmOjMwMDAwOTg2OTM0NjcwMjo6MDo6&url=%2FASUS-ROG-Three-Layer-Hot-Swappable-PBT%2Fdp%2FB0BSKX8W3B%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2JMHJSLJJO26M%26keywords%3Dgaming%2Bkeyboard%26qid%3D1688964200%26sprefix%3D%252Caps%252C310%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozNjczNzg4NjU4MzU0ODU5OjE2ODg5NjQyMDA6c3BfYXRmOjIwMDAxNjEzNTU4MjMxMTo6MDo6&url=%2FSteelSeries-Compact-Mechanical-Gaming-Keyboard%2Fdp%2FB07TGQ7CNF%2Fref%3Dsr_1_2_sspa%3Fcrid%3D2JMHJSLJJO26M%26keywords%3Dgaming%2Bkeyboard%26qid%3D1688964200%26sprefix%3D%252Caps%252C310%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.com/SteelSeries-Apex-RGB-Gaming-Keyboard/dp/B07ZGDPT4M/ref=sr_1_3?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-3',
#  'https://www.amazon.com/Razer-Ornata-Gaming-Keyboard-Low-Profile/dp/B09X6GJ691/ref=sr_1_4?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-4',
#  'https://www.amazon.com/Corsair-Backlighting-Integration-Resistant-Dedicated/dp/B09ZVLBP4M/ref=sr_1_5?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-5',
#  'https://www.amazon.com/Razer-DeathStalker-Wireless-Gaming-Keyboard/dp/B0BM2YKK7F/ref=sr_1_6?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-6',
#  'https://www.amazon.com/Corsair-Mechanical-Gaming-Keyboard-Hyper-Polling/dp/B09NMM4FY6/ref=sr_1_7?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-7',
#  'https://www.amazon.com/SteelSeries-Apex-Mechanical-Gaming-Keyboard/dp/B07SWNSXQN/ref=sr_1_8?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-8',
#  'https://www.amazon.com/Razer-BlackWidow-Mechanical-Gaming-Keyboard/dp/B08FQPLCNC/ref=sr_1_9?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-9',
#  'https://www.amazon.com/Corsair-Optical-Mechanical-Gaming-Keyboard-Hyper-Polling/dp/B0B9RLFYHW/ref=sr_1_10?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-10',
#  'https://www.amazon.com/Ractous-Bluetooth-Mechanical-Dye-Sublimation-Programmable-Black/dp/B09CPV6T4C/ref=sr_1_11?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-11',
#  'https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozNjczNzg4NjU4MzU0ODU5OjE2ODg5NjQyMDA6c3BfbXRmOjIwMDAxNjEzNTU4MjExMTo6MDo6&url=%2FSteelSeries-Apex-Mechanical-Gaming-Keyboard%2Fdp%2FB07SWNSXQN%2Fref%3Dsr_1_12_sspa%3Fcrid%3D2JMHJSLJJO26M%26keywords%3Dgaming%2Bkeyboard%26qid%3D1688964200%26sprefix%3D%252Caps%252C310%26sr%3D8-12-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9tdGY%26psc%3D1',
#  'https://www.amazon.com/Logitech-Mechanical-Tenkeyless-Detachable-LIGHTSYNC/dp/B07QQB9VCV/ref=sr_1_13?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-13',
#  'https://www.amazon.com/Logitech-Backlit-Mechanical-Gaming-Keyboard/dp/B01CDYB8AG/ref=sr_1_14?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-14',
#  'https://www.amazon.com/Razer-Huntsman-Elite-Gaming-Keyboard/dp/B085TD1TV2/ref=sr_1_15?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-15',
#  'https://www.amazon.com/Razer-BlackWidow-Mechanical-Gaming-Keyboard/dp/B0BV4BC7LV/ref=sr_1_16?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-16',
#  'https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozNjczNzg4NjU4MzU0ODU5OjE2ODg5NjQyMDA6c3BfbXRmOjIwMDA2NjgwMzAxMTY5ODo6MDo6&url=%2FSteelSeries-Wireless-Mechanical-Gaming-Keyboard%2Fdp%2FB0B16JFF54%2Fref%3Dsr_1_17_sspa%3Fcrid%3D2JMHJSLJJO26M%26keywords%3Dgaming%2Bkeyboard%26qid%3D1688964200%26sprefix%3D%252Caps%252C310%26sr%3D8-17-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9tdGY%26psc%3D1',
#  'https://www.amazon.com/ASUS-ROG-Three-Layer-Hot-Swappable-PBT/dp/B0BSKX8W3B/ref=sr_1_18?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-18',
#  'https://www.amazon.com/Cooler-Master-Wireless-Mechanical-Keyboard/dp/B08LX76NKR/ref=sr_1_19?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-19',
#  'https://www.amazon.com/ASUS-Mechanical-Programmable-Passthrough-Resistance/dp/B08TZVGNZJ/ref=sr_1_20?crid=2JMHJSLJJO26M&keywords=gaming+keyboard&qid=1688964200&sprefix=%2Caps%2C310&sr=8-20',
#  'https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozNjczNzg4NjU4MzU0ODU5OjE2ODg5NjQyMDA6c3BfYnRmOjMwMDAxMTkwODIzNTcwMjo6MDo6&url=%2FSteelSeries-Worlds-Fastest-Mechanical-Keyboard%2Fdp%2FB0BF64DN6H%2Fref%3Dsr_1_21_sspa%3Fcrid%3D2JMHJSLJJO26M%26keywords%3Dgaming%2Bkeyboard%26qid%3D1688964200%26sprefix%3D%252Caps%252C310%26sr%3D8-21-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9idGY%26psc%3D1',
#  'https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozNjczNzg4NjU4MzU0ODU5OjE2ODg5NjQyMDA6c3BfYnRmOjIwMDE3NjkyMDA3NDA5ODo6MDo6&url=%2FVulcan-Aimo-Mechanical-Gaming-Keyboard%2Fdp%2FB07YNHBVGQ%2Fref%3Dsr_1_22_sspa%3Fcrid%3D2JMHJSLJJO26M%26keywords%3Dgaming%2Bkeyboard%26qid%3D1688964200%26sprefix%3D%252Caps%252C310%26sr%3D8-22-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9idGY%26psc%3D1']

# %%
data = pd.DataFrame({'ProductId': product_code,'Name':product_name,
                         'Price': product_price, 'Link':product_link,'Rating':product_ratings,'Rating Count':product_ratings_num,
                         })

# %%
data
# Out:
#      ProductId                                               Name   Price  \
# 0   B0BSKX8W3B  ASUS ROG Azoth 75% Wireless DIY Custom Gaming ...  249.99
# 1   B07TGQ7CNF  SteelSeries Apex 7 TKL Compact Mechanical Gami...  109.99
# 2   B07ZGDPT4M  SteelSeries Apex 3 RGB Gaming Keyboard – 10-Zo...   24.98
# 3   B09X6GJ691  Razer Ornata V3 X Gaming Keyboard: Low-Profile...   34.98
# 4   B07QQB9VCV  Logitech G PRO Mechanical Gaming Keyboard, Ult...       0
# 5   B09ZVLBP4M  Corsair K55 PRO LITE RGB Wired Membrane Gaming...   29.99
# 6   B0BV4BC7LV  Razer BlackWidow V4 Pro Wired Mechanical Gamin...  229.99
# 7   B0BM2YKK7F  Razer DeathStalker V2 Pro Wireless Gaming Keyb...  249.99
# 8   B09NMM4FY6  Corsair K70 RGB PRO Mechanical Gaming Keyboard...  119.99
# 9   B0B9RLFYHW  Corsair K70 PRO RGB Optical-USB-C Mechanical G...  162.00
# 10  B0BQ7DLR2V  ROCCAT Magma Mini - 60% RGB Gaming Keyboard wi...   34.99
# 11  B07SWNSXQN  SteelSeries Apex 7 Mechanical Gaming Keyboard ...  116.29
# 12  B01CDYB8AG  Logitech G610 Orion Red Backlit Mechanical Gam...       0
# 13  B0BDP9K97M  Logitech G815 LIGHTSYNC RGB Mechanical Gaming ...       0
# 14  B08FQPLCNC  Razer BlackWidow V3 Mechanical Gaming Keyboard...   99.99
# 15  B09CPV6T4C  Ractous RTK61BP 60% Wireless Mechanical Gaming...   15.99
# 16  B0BF64DN6H  New SteelSeries Apex Pro TKL 2023 Ed.- World's...  189.99
# 17  B07SWNSXQN  SteelSeries Apex 7 Mechanical Gaming Keyboard ...  116.29
# 18  B0BSKX8W3B  ASUS ROG Azoth 75% Wireless DIY Custom Gaming ...  249.99
# 19  B08XBQ79MN  HyperX Alloy Origins 60 - Mechanical Gaming Ke...       0
# 20  B07YNHBVGQ  ROCCAT Vulcan 121 AIMO Linear Mechanical Titan...   79.99
# 21  B09X6FKCBD  Razer Ornata V3 Gaming Keyboard: Low-Profile K...   59.99
#
#                                                  Link              Rating  \
# 0   https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.6 out of 5 stars
# 1   https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.7 out of 5 stars
# 2   https://www.amazon.com/SteelSeries-Apex-RGB-Ga...  4.7 out of 5 stars
# 3   https://www.amazon.com/Razer-Ornata-Gaming-Key...  4.7 out of 5 stars
# 4   https://www.amazon.com/Logitech-Mechanical-Ten...  4.7 out of 5 stars
# 5   https://www.amazon.com/Corsair-Backlighting-In...  4.6 out of 5 stars
# 6   https://www.amazon.com/Razer-BlackWidow-Mechan...  4.5 out of 5 stars
# 7   https://www.amazon.com/Razer-DeathStalker-Wire...  4.3 out of 5 stars
# 8   https://www.amazon.com/Corsair-Mechanical-Gami...  4.5 out of 5 stars
# 9   https://www.amazon.com/Corsair-Optical-Mechani...  4.7 out of 5 stars
# 10  https://www.amazon.com/ROCCAT-Magma-Mini-Progr...  4.6 out of 5 stars
# 11  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.6 out of 5 stars
# 12  https://www.amazon.com/Logitech-Backlit-Mechan...  4.6 out of 5 stars
# 13  https://www.amazon.com/Logitech-G815-Mechanica...  4.6 out of 5 stars
# 14  https://www.amazon.com/Razer-BlackWidow-Mechan...  4.7 out of 5 stars
# 15  https://www.amazon.com/Ractous-Bluetooth-Mecha...  4.4 out of 5 stars
# 16  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.3 out of 5 stars
# 17  https://www.amazon.com/SteelSeries-Apex-Mechan...  4.6 out of 5 stars
# 18  https://www.amazon.com/ASUS-ROG-Three-Layer-Ho...  4.6 out of 5 stars
# 19  https://www.amazon.com/HyperX-Alloy-Origins-Me...  4.7 out of 5 stars
# 20  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.6 out of 5 stars
# 21  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.7 out of 5 stars
#
#    Rating Count
# 0            71
# 1         2,342
# 2         9,796
# 3        11,136
# 4         4,816
# 5        13,953
# 6           115
# 7           286
# 8            20
# 9        11,218
# 10          655
# 11        2,001
# 12        2,172
# 13       11,072
# 14        3,294
# 15          196
# 16          210
# 17        2,001
# 18           71
# 19        8,526
# 20        2,018
# 21       11,136

# %%
next_page = driver.find_element(By.XPATH, './/a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
next_page.click()

# %% [markdown]
# ## Crawl Multiple pages

# %%
import pandas as pd
import re
import datetime
from pandas import DataFrame
import undetected_chromedriver as uc
from time import sleep
from selenium.common import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import ElementNotInteractableException
import urllib.request
import os
from dotenv import load_dotenv
from PIL import Image
from pytesseract import pytesseract

# %%
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
driver = uc.Chrome(options=options)

# %%
driver.get('https://www.amazon.com/')

# %% [markdown]
# ### Captcha

# %%
while True:
    try:
        captcha_image = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
            (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-row.a-spacing-large > div > div > div.a-row.a-text-center > img")))
        image = captcha_image.get_attribute('src')
        filename = datetime.datetime.now()
        image_path = 'D:\CrawlDataAmazon\\'
        folder_path = os.path.join(os.path.dirname(image_path), "data")
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        urllib.request.urlretrieve(image, os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S"))))
        
        # check folder
        if os.path.exists(folder_path):
            files = os.listdir(folder_path)
            if len(files) > 1:
                files.sort(key=lambda x: os.path.getmtime(os.path.join(folder_path, x)), reverse=True)
                for file in files[1:]:
                    file_path = os.path.join(folder_path, file)
                    os.remove(file_path)
            print("List images:")
            for file in os.listdir(folder_path):
                print(file)
        else:
            print("Folder not found.")
        
        path_to_tesseract = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
        path_to_image = os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S")))
        pytesseract.tesseract_cmd = path_to_tesseract
        img = Image.open(path_to_image)

        #Extract text from image
        text = pytesseract.image_to_string(img)
        print(text)
        
        captcha = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
            (By.CSS_SELECTOR, "#captchacharacters")))
        captcha.send_keys(text)
        sleep(2)
        
        submit = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
            (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-section.a-spacing-extra-large > div > span > span > button")))
        submit.click()
    except TimeoutException:
        break

# %%
product_name = []
product_code = []
product_price = []
product_ratings = []
product_ratings_num = []
product_link = []

# %% [markdown]
# ### Crawl end of page

# %%
# count = 1
# while True:
#     try:
#         print(f'Page {count}')
#         items = WebDriverWait(driver,10).until(EC.presence_of_all_elements_located(
#         (By.XPATH, '//div[contains(@class, "s-result-item s-asin")]')))
#         for item in items:
#             try:
#                 name = item.find_element(By.XPATH, './/span[@class="a-size-medium a-color-base a-text-normal"]')
#                 product_name.append(name.text)
#             except:
#                 product_name.append("")

#             try:
#                 data_code = item.get_attribute("data-asin")
#                 product_code.append(data_code)
#             except:
#                 product_code.append("")

#             # find price
#             whole_price = item.find_elements(By.XPATH, './/span[@class="a-price-whole"]')
#             fraction_price = item.find_elements(By.XPATH, './/span[@class="a-price-fraction"]')

#             if whole_price != [] and fraction_price != []:
#                 price = '.'.join([whole_price[0].text, fraction_price[0].text])
#             else:
#                 price = 0
#             product_price.append(price)

#             # find ratings box
#             ratings_box = item.find_elements(By.XPATH, './/div[@class="a-row a-size-small"]/span')

#             # find ratings and ratings_num
#             if ratings_box != []:
#                 ratings = ratings_box[0].get_attribute('aria-label')
#                 ratings_num = ratings_box[1].get_attribute('aria-label')
#             else:
#                 ratings, ratings_num = 0, 0

#             product_ratings.append(ratings)
#             product_ratings_num.append(str(ratings_num))

#             # find link
#             link = item.find_element(By.XPATH, './/a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]').get_attribute("href")
#             product_link.append(link)
#         next_page = driver.find_element(By.XPATH, './/a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
#         count +=1
#         next_page.click()
#         sleep(2)
#     except ElementNotInteractableException:
#         print('Element Not Interactable Exception')
#         break

# %% [markdown]
# ### Crawl 3 pages

# %%
for i in range(4):
    try:
        print(f'Page {i}')
        items = WebDriverWait(driver,10).until(EC.presence_of_all_elements_located(
        (By.XPATH, '//div[contains(@class, "s-result-item s-asin")]')))
        for item in items:
            try:
                name = item.find_element(By.XPATH, './/span[@class="a-size-medium a-color-base a-text-normal"]')
                product_name.append(name.text)
            except:
                product_name.append("")

            try:
                data_code = item.get_attribute("data-asin")
                product_code.append(data_code)
            except:
                product_code.append("")

            # find price
            whole_price = item.find_elements(By.XPATH, './/span[@class="a-price-whole"]')
            fraction_price = item.find_elements(By.XPATH, './/span[@class="a-price-fraction"]')

            if whole_price != [] and fraction_price != []:
                price = '.'.join([whole_price[0].text, fraction_price[0].text])
            else:
                price = 0
            product_price.append(price)

            # find ratings box
            ratings_box = item.find_elements(By.XPATH, './/div[@class="a-row a-size-small"]/span')

            # find ratings and ratings_num
            if ratings_box != []:
                ratings = ratings_box[0].get_attribute('aria-label')
                ratings_num = ratings_box[1].get_attribute('aria-label')
            else:
                ratings, ratings_num = 0, 0

            product_ratings.append(ratings)
            product_ratings_num.append(str(ratings_num))

            # find link
            link = item.find_element(By.XPATH, './/a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]').get_attribute("href")
            product_link.append(link)
        next_page = driver.find_element(By.XPATH, './/a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
        count +=1
        next_page.click()
        sleep(2)
    except ElementNotInteractableException:
        print('Element Not Interactable Exception')
        break

# %%
data = pd.DataFrame({'ProductId': product_code,'Name':product_name,
                         'Price': product_price, 'Link':product_link,'Rating':product_ratings,'Rating Count':product_ratings_num,
                         })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 data = pd.DataFrame({'ProductId': product_code,'Name':product_name,
#       2                          'Price': product_price, 'Link':product_link,'Rating':product_ratings,'Rating Count':product_ratings_num,
#       3                          })
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
product_name
# Out:
# ['ASUS ROG Azoth 75% Wireless DIY Custom Gaming Keyboard, OLED Display, Three-Layer Dampening, Hot-Swappable ROG NX Red Switches & Keyboard Stabilizers, PBT Keycaps, RGB-Black',
#  "New SteelSeries Apex Pro TKL 2023 Ed.- World's Fastest Mechanical Gaming Keyboard - Adjustable Actuation - Esports Tenkeyless - OLED Screen - RGB - PBT Keycaps - USB-C",
#  'SteelSeries Apex 3 RGB Gaming Keyboard – 10-Zone RGB Illumination – IP32 Water Resistant – Premium Magnetic Wrist Rest (Whisper Quiet Gaming Switch)',
#  'Razer Ornata V3 X Gaming Keyboard: Low-Profile Keys - Silent Membrane Switches - Spill Resistant - Chroma RGB Lighting - Ergonomic Wrist Rest - Classic Black',
#  'Logitech G PRO Mechanical Gaming Keyboard, Ultra Portable Tenkeyless Design, Detachable Micro USB Cable, 16.8 Million Color LIGHTSYNC RGB Backlit Keys',
#  'Corsair K55 PRO LITE RGB Wired Membrane Gaming Keyboard (5-Zone Dynamic RGB Backlighting, Six Macro Keys with Stream Deck Integration, IP42 Dust and Spill Resistant, Dedicated Media Keys) Black',
#  'Razer BlackWidow V4 Pro Wired Mechanical Gaming Keyboard: Yellow Mechanical Switches - Linear & Silent - Doubleshot ABS Keycaps - Command Dial - Programmable Macros - Chroma RGB - Magnetic Wrist Rest',
#  'Razer DeathStalker V2 Pro Wireless Gaming Keyboard: Low-Profile Optical Switches - Clicky Purple - HyperSpeed Wireless & Bluetooth 5.0-40 Hr Battery - Ultra-Durable Coated Keycaps - RGB - White',
#  'Corsair K70 PRO RGB Optical-USB-C Mechanical Gaming Keyboard - OPX Linear Switches, PBT Double-Shot Keycaps, 8,000Hz Hyper-Polling, Magnetic Soft-Touch Palm Rest - NA Layout, QWERTY - Black',
#  'Corsair K70 RGB PRO Mechanical Gaming Keyboard - Cherry MX Brown Keyswitches - 8,000Hz Hyper-Polling - Durable PBT Double-Shot Keycaps - Magnetic Soft-Touch Palm Rest - Black (QWERTY - NA Layout)',
#  'ROCCAT Magma Mini - 60% RGB Gaming Keyboard with 5 Programmable Lighting Zones, Membrane Key switches, Programmable Function Layers, Anti-Ghosting, & Spill Resistance - Black',
#  'SteelSeries Apex 7 TKL Compact Mechanical Gaming Keyboard – OLED Smart Display – USB Passthrough and Media Controls – Linear and Quiet – RGB Backlit (Red Switch)',
#  'Logitech G610 Orion Red Backlit Mechanical Gaming Keyboard',
#  'Logitech G815 LIGHTSYNC RGB Mechanical Gaming Keyboard with Low Profile GL Tactile Key Switch, 5 programmable G-Keys,USB Passthrough, Dedicated Media Control, Black and White colorways',
#  'Razer BlackWidow V3 Mechanical Gaming Keyboard: Green Mechanical Switches - Tactile & Clicky - Chroma RGB Lighting - Compact Form Factor - Programmable Macro Functionality, Classic Black',
#  'Ractous RTK61BP 60% Wireless Mechanical Gaming Keyboard,RGB Blacklit PBT Sublimation Keycaps 61keys Bluetooth5.1/Wried Gaming Keyboard for PC/Mac Gamers,Hot-Swap Gateron Optical Red Switch-Black',
#  'SteelSeries Apex 7 Mechanical Gaming Keyboard – OLED Smart Display – USB Passthrough and Media Controls – Linear , Quiet – RGB Backlit (Red Switch)',
#  'SteelSeries Apex 7 Mechanical Gaming Keyboard – OLED Smart Display – USB Passthrough and Media Controls – Linear , Quiet – RGB Backlit (Red Switch)',
#  'ASUS ROG Azoth 75% Wireless DIY Custom Gaming Keyboard, OLED Display, Three-Layer Dampening, Hot-Swappable ROG NX Red Switches & Keyboard Stabilizers, PBT Keycaps, RGB-Black',
#  'SteelSeries Apex Pro USB Mechanical Gaming Keyboard – Adjustable Actuation Switches – World’s Fastest Mechanical Keyboard – OLED Smart Display – RGB Backlit',
#  'ROCCAT Vulcan 121 AIMO Linear Mechanical Titan Switch Full-size PC Gaming Keyboard with Per-key AIMO RGB Lighting, Anodized Aluminum Top Plate and Detachable Palm Rest – Black',
#  'Razer Ornata V3 Gaming Keyboard: Low-Profile Keys - Mecha-Membrane Switches - UV-Coated Keycaps - Backlit Media Keys - 10-Zone RGB Lighting - Spill-Resistant - Magnetic Wrist Wrest - Classic Black',
#  'HyperX Pulsefire Haste 2 – Wired Gaming Mouse- Ultra Lightweight, 53g, 8000Hz Polling Rate, Precision Sensor, Hyperflex 2 Cable, Plug and Play – Black',
#  'HyperX Alloy Origins 60 - Mechanical Gaming Keyboard, Ultra Compact 60% Form Factor, Double Shot PBT Keycaps, RGB LED Backlit, NGENUITY Software Compatible - Linear HyperX Red Switch',
#  'HyperX Alloy Core RGB – Membrane Gaming Keyboard, Comfortable Quiet Silent Keys with RGB LED Lighting Effects, Spill Resistant, Dedicated Media Keys, Compatible with Windows 10/8.1/8/7 – Black',
#  'Razer Huntsman Mini 60% Gaming Keyboard: Fast Keyboard Switches - Linear Optical Switches - Chroma RGB Lighting - PBT Keycaps - Onboard Memory - Classic Black',
#  'Cherry MX 3.0 S Wired Mechanical Gaming Keyboard. Aluminum Housing Built for Gamers w/MX Red Silent Switches. RGB Backlit Color Display Over 16m Colors. from The Makers of MX. Full Size. Pure White.',
#  'ASUS ROG Strix Scope RX Gaming Keyboard | Optical Mechanical Blue Switches, Programmable Macro, Aura Sync RGB Lighting, USB 2.0 Passthrough, IP57 Waterproof & Dust Resistance, Alloy Top Plate, Black',
#  'Logitech G613 LIGHTSPEED Wireless Mechanical Gaming Keyboard, Multihost 2.4 GHz + Blutooth Connectivity - Black',
#  'Razer Tartarus V2 Gaming Keypad: Mecha-Membrane Key Switches - One Handed Keyboard - 32 Programmable Keys - Customizable Chroma RGB Lighting - Programmable Macros - Classic Black',
#  'EVGA Z20 RGB Optical Mechanical USB Gaming Keyboard, Optical Mechanical Switches (Linear), 811-W1-20US-KR',
#  'Razer RZ01-02410100-R3U1 19-Button Gaming Mouse, Black & Razer Ornata RGB Mecha-Membrane Keyboard, Black',
#  'ROCCAT Vulcan II Max – Optical-Mechanical PC Gaming Keyboard with Customizable RGB Illuminated Keys and Palm Rest, Titan II Smooth Linear Switches, Aluminum Plate, 100M Keystroke Durability – White',
#  'Cooler Master CK720 Hot-Swappable 65% Space Gray Mechanical Gaming Keyboard, Kailh Box V2 Tactile Brown Switches, Customizable RGB, USB-C Connectivity, 3-Way Dial, QWERTY (CK-720-GKKM1-US)',
#  'SteelSeries Apex 7 TKL Compact Mechanical Gaming Keyboard – OLED Smart Display – USB Passthrough and Media Controls – Linear and Quiet – RGB Backlit (Red Switch)',
#  'ASUS ROG Strix Scope II 96 Wireless Gaming Keyboard, Tri-Mode Connection, Dampening Foam & Switch-Dampening Pads, Hot-Swappable Pre-lubed ROG NX Snow Switches, PBT Keycaps, RGB-Black',
#  'ROCCAT Vulcan Pro Linear Optical PC Gaming Keyboard, Titan Switch Full Size with Per Key AIMO RGB Lighting, Anodized Aluminum Top Plate and Detachable Palm/Wrist Rest, Low Profile, Black',
#  'Logitech G915 TKL Tenkeyless Lightspeed RGB Mechanical Gaming Keyboard, Low Profile Switch Options, LIGHTSYNC RGB, Advanced Wireless and Bluetooth Support - Tactile (Renewed)',
#  'SteelSeries Aerox 5 Wireless – Diablo IV Edition – Lightweight 76g Gaming Mouse – 18000 CPI – TrueMove Air Optical Sensor – Water Resistant – 180+ Hour Battery Life – Free in-Game Item - PC/MAC',
#  'Logitech G305 Lightspeed Wireless Gaming Mouse - Black & 13 Prodigy Gaming Keyboard, LIGHTSYNC RGB Backlit Keys, Spill-Resistant, Customizable Keys, Dedicated Multi-Media Keys – Black',
#  'Razer Huntsman V2 Analog Gaming Keyboard - Classic Black & Basilisk V3 Customizable Ergonomic Gaming Mouse - Classic Black & Goliathus Extended Chroma Gaming Mousepad - Classic Black',
#  'IOGEAR Kaliber Gaming Wireless Gaming Keyboard and Mouse Combo, GKM602R',
#  'ProtoArc Wireless Ergonomic Keyboard, EK01-NL Ergo Split Keyboard with Wrist Rest, Natural Typing, Multi-Device, Bluetooth and USB Connectivity, Rechargeable, Windows/Mac/Android - Basic Version',
#  'Logitech G Pro TKL Mechanical Wired Gaming Keyboard GX Blue Clicky Switch and LIGHTSYNC RGB Backlit Keys, 12 programmable F-key macros, Black - 920-009388 (Renewed)',
#  'Razer Huntsman Elite Gaming Keyboard: Fast Keyboard Switches - Linear Optical Switches - Chroma RGB Lighting - Magnetic Plush Wrist Rest - Dedicated Media Keys & Dial - Classic Black',
#  'EVGA Z12 RGB Gaming Keyboard, RGB Backlit LED, 5 Programmable Macro Keys, Dedicated Media Keys, Water Resistant, 834-W0-12US-KR, Black',
#  'ASUS RGB Mechanical Gaming Keyboard - ROG Strix Scope TKL | Cherry MX Red Switches | 2X Wider Ctrl Key for FPS Precision | Gaming Keyboard for PC',
#  'ASUS ROG Claymore II 100% / 80% TKL Wireless RGB Modular Gaming Keyboard, ROG RX Red Switches, PBT Doubleshot Keycaps, Detachable Numpad, Wrist Rest, Media Controls, USB Passthrough - Black PBT',
#  'MSI Vigor GK71 Sonic Blue US Mechanical RGB Gaming Keyboard Sonic Blue Switches',
#  'Razer Turret Wireless Mechanical Gaming Keyboard & Mouse Combo for PC, Xbox One, Xbox Series X & S: Chroma RGB/Dynamic Lighting - Retractable Magnetic Mouse Mat - 40hr Battery, Classic Black',
#  'Corsair K60 RGB Pro SE Mechanical Gaming Keyboard - CHERRY Mechanical Keyswitches - Durable AluminumFrame - Customizable Per-Key RGB Backlighting - PBT Double-Shot Keycaps - Detachable Palm Rest,Black',
#  'ROCCAT Vulcan TKL Linear PC Gaming Keyboard, Titan Switch Mechanical with Per Key AIMO RGB Lighting, Tenkeyless, Compact Design, Anodized Aluminum Top Plate, Detachable USB-C Cable, Black',
#  'SteelSeries USB Apex Pro TKL Mechanical Gaming Keyboard – World’s Fastest Mechanical Switches – OLED Smart Display – Compact Form Factor – RGB Backlit',
#  'IOGEAR KeyMander 2 Keyboard/Mouse Adapter Plus Controller Crossover- GE1337P2, Black',
#  'Acer Predator Aethon 303 Wired Gaming Keyboard - Kailh Blue Mechanical Switches | RGB Illuminated Keyboard | 12 Backlight Effects | 5 Pre-Set Gaming Modes & 3 Sidelight Effects | 100% Anti-Ghosting',
#  'Corsair K95 RGB PLATINUM XT Mechanical Wired Gaming Keyboard - Cherry MX Speed Switches - PBT Double-Shot Keycaps - iCUE Compatible - QWERTY NA Layout - Black',
#  'Razer BlackWidow V3 Mini HyperSpeed 65% Wireless Mechanical Gaming Keyboard: HyperSpeed Wireless Technology -Yellow Mechanical Switches- Linear & Silent - Phantom Pudding Keycaps - 200Hrs Battery Life',
#  'YUNZII Sakura Kitty Dye Sub Keycaps, 120 Pudding Keycaps Sublimation PBT Custom Keycaps with Key Puller for Cherry Gateron MX Switches Mechanical Gaming Keyboard (KSA Profile, Sakura Kitty)',
#  'Cooler Master SK622 60% Wireless Bluetooth Silver/White Mechanical Low Profile Gaming Keyboard, Click Blue Switches, Customizable RGB, Ergonomic Design, Mac/Windows, QWERTY (SK-622-SKTL1-US)',
#  'ROCCAT Vulcan 122 Mechanical PC Tactile Gaming Keyboard, Titan Switch, AIMO RGB Backlit Lighting Per Key, Detachable Palm/Wrist Rest, Anodized Aluminum Top Plate, Full Size, White/Silver',
#  'Alienware Low-Profile RGB Gaming Keyboard AW510K: Alienfx Per Key RGB LED - Media CONTROLS & USB Passthrough - Cherry MX Low Profile Red Switches',
#  'Razer Huntsman V2 TKL Tenkeyless Gaming Keyboard: Fast Linear Optical Switches Gen2 & 8000Hz Polling Rate - Detachable Type-C Cable - PBT Keycaps - Ergonomic Wrist Rest - Quartz Pink',
#  'Fiodio Rainbow Membrane Gaming Keyboard, Quiet Wired Computer Keyboard, 104 Silent & 26 Anti-Ghosting Keys, Spill Resistant, Multimedia Control for PC and Desktop',
#  'Corsair K70 PRO MINI WIRELESS RGB 60% Mechanical Gaming Keyboard (Fastest Sub-1ms Wireless, Swappable CHERRY MX Red Keyswitches, Aluminum Frame, PBT Double-Shot Keycaps) QWERTY, NA Layout - Black',
#  'DURGOD TGK 021 Mechanical Gaming Keyboard, RGB Backlit and Magnetic Wrist Rest, Kailh Turbo Gaming Red Switch, Durable PBT Keycap and Hot Swappable with 104 Keys, Full Size Wired Keyboard for PC Mac',
#  'CORSAIR K57 RGB Wireless Gaming Keyboard - <1ms response time with Slipstream Wireless - Connect with USB dongle, Bluetooth or wired - Individually Backlit RGB Keys, Black',
#  'Anivia 87 Keys Mechanical Gaming Keyboard, 80% Compact USB Wired Mechanical Keyboard with Red Backlit & Blue Switch, Hot Swappable Gaming Keyboard for Gaming and Work - Black',
#  'Corsair K60 PRO TKL Wired Optical-Mechanical OPX Linear Switch Gaming Keyboard with 8000Hz Polling Rate - Black',
#  'Corsair K70 PRO Mini Wireless RGB 60% Mechanical Gaming Keyboard - Fastest Sub-1ms Wireless, Swappable Cherry MX Brown Keyswitches, Aluminum Frame, PBT Double-Shot Keycaps - NA Layout, QWERTY - White',
#  'MSI Vigor GK30 Combo White, 6-Zone RGB GK30 Gaming Keyboard & GM11 Gaming Mouse, Water Repellent & Splash-Proof, 5000 DPI',
#  'IOGEAR KeyMander 2 3Play Keyboard/Mouse Sharing Switch for PC and Game Consoles - GES1337',
#  'SteelSeries Apex Pro Mini Wireless Mechanical Gaming Keyboard – World’s Fastest Keyboard – Adjustable Actuation – Compact 60% Form Factor – RGB – PBT Keycaps – Bluetooth 5.0 – 2.4GHz – USB-C',
#  'YUNZII YZ75 75% Hot Swappable Wireless Gaming Mechanical Keyboard, RGB Backlights, BT5.0/2.4G/USB-C, Dye Sub PBT Keycaps for Linux/Win/Mac(Gateron G Pro Yellow, Black)',
#  'SteelSeries New Apex 9 TKL – HotSwap Optical Mini Keyboard – TKL Esports Design – Optical Switches – RGB Customization – Aluminum Alloy Frame – Double Shot PBT Keycaps',
#  'Corsair K100 AIR Wireless RGB Mechanical Gaming Keyboard - Ultra-Thin, Sub-1ms Slipstream , Low-Latency Bluetooth, Cherry MX Ultra Low Profile Keyswitches - NA Layout, QWERTY - Black',
#  'EVGA Z15 RGB USB Gaming Keyboard, RGB Backlit LED, Hotswappable Mechanical Kailh Speed Silver Switches (Linear), 821-W1-15US-KR, Black',
#  'ASUS TUF Gaming Keyboard Mouse Combo | K1 RGB Keyboard, M3 Lightweight Mouse, Aura Sync RGB Lighting, Comfortable & Rugged Design, Armoury Crate Software, Programmable Buttons for PC Gamers',
#  'Logitech G413 Backlit Mechanical Gaming Keyboard with USB Passthrough – Carbon',
#  'DROP ALT Mechanical Keyboard — 65% (67 Key) Gaming Keyboard, Hot-Swap Switches, Programmable Macros, RGB LED Backlighting, USB-C, Doubleshot PBT, Aluminum Frame (Cherry MX Brown, Black)',
#  'YUNZII X75 PRO 82 Key Wireless Hot Swappable Mechanical Gaming Keyboard with Transparent Keycaps,BT5.0/2.4G/USB-C, Gasket Mount Keyboard,for Windows/Mac (Crystal White Switch, Wireless-Pink)',
#  'MSI Gaming Backlit RGB Dedicated Hotkeys Anti-Ghosting Water Resistant Gaming Keyboard (Vigor GK20 US), Black',
#  'Razer BlackWidow V3 Tenkeyless TKL Mechanical Gaming Keyboard: Yellow Mechanical Switches - Linear & Silent - Chroma RGB Lighting - Compact Form Factor - Programmable Macros - USB Passthrough',
#  'Logitech G G703 6-Button Wireless Gaming Mouse, USB Black & Logitech G G613 Lightspeed Wireless Gaming Keyboard, Black',
#  'Razer Power Up Gaming Bundle V2 black',
#  'Rosewill NEON K52 Wired Waterproof Gaming Keyboard, Mem-chanical Switches, 8 RGB LED Backlight Effects, 104 Keys, 19-Key Anti-Ghosting, 12 Multimedia Hotkeys, Spill-Proof Dust-Proof Aluminum Plate',
#  'Corsair K65 RGB MINI 60% Mechanical Gaming Keyboard (Customizable Per-Key RGB Backlighting, CHERRY MX Speed Mechanical Keyswitches, Detachable USB Type-C Cable, AXON Hyper-Processing Technology) Black',
#  'MSI Vigor GK30 Combo, 6-Zone RGB GK30 Gaming Keyboard & GM11 Gaming Mouse, Water Repellent & Splash-Proof, 5000 DPI',
#  'ROCCAT Vulcan II Max – Optical-Mechanical PC Gaming Keyboard with Customizable RGB Illuminated Keys and Palm Rest, Titan II Tactile Linear Switches, Aluminum Plate, 100M Keystroke Durability – Black',
#  'IOGEAR KeyMander 2 & GKM602R Combo - GE1337P2KIT',
#  'ROCCAT Vulcan II Max – Optical-Mechanical PC Gaming Keyboard with Customizable RGB Illuminated Keys and Palm Rest, Titan II Smooth Linear Switches, Aluminum Plate, 100M Keystroke Durability – White',
#  'HyperX Alloy Elite 2 – Mechanical Gaming Keyboard, Software-Controlled Light & Macro Customization, ABS Pudding Keycaps, Media Controls, RGB LED Backlit, Linear Switch, HyperX Red',
#  'Alienware USB Low-Profile RGB Gaming Keyboard AW410K: Alienfx Per Key RGB LED - Cherry MX Brown Switches',
#  'ASUS ROG Strix Flare (Cherry MX Brown) Aura Sync RGB Mechanical Gaming Keyboard with Switches, Customizable Badge, USB Pass Through and Media Controls',
#  'Lenovo GY40T26478 Legion K500 RGB Mechanical Gaming Keyboard, 3 ZONE Full-size Keyboard, 7 user Programmable Hot Keys; 16.8 Million Colors, 50 Million-Click Red Mechanical Keys, Detachable Palm Rest',
#  'Fiodio Mechanical Gaming Keyboard, LED Rainbow Gaming Backlit, 104 Anti-ghosting Keys, Quick-Response Black Switches, Multimedia Control for PC and Desktop Computer, with Removable Hand Rest',
#  'NZXT Function Full-Size USB Gaming Keyboard – Gateron Red Mechanical Switches: Linear, Fast, and Quiet – Hot-Swappable – RGB Backlit – Aluminum Top Plate – Sound Dampening Foam – Wrist Rest – Black',
#  'EVGA USB Z20 RGB Optical Mechanical Gaming Keyboard, Optical Mechanical Switches (Clicky), 812-W1-20US-KR, Black',
#  'Redragon K503 Wireless Gaming Keyboard, RGB LED Backlit, Multimedia Keys, Silent Membrane Keyboard with Wrist Rest for Windows PC Games (Black)',
#  'ASUS ROG Strix Scope RX TKL Wireless Deluxe - 80% Gaming Keyboard, Tri-Mode Connectivity (2.4GHz RF, Bluetooth, Wired), ROG RX Red Optical Mechanical Switches, PBT Keycaps, RGB, Wrist Rest, Black',
#  'Mechanical Gaming Keyboard - MK1 RED LED Backlit Mechanical Keyboards - Small Compact 87 Key Metal Mechanical Computer Keyboard USB Wired Blue Equivalent Switches for Windows PC Gamers - Black',
#  'New Alienware Low-Profile RGB Gaming Keyboard AW510K Light, Alienfx Per Key RGB Lighting, Media Controls and USB Passthrough, Cherry MX Low Profile Red Switches, Lunar light',
#  'MSI Vigor GK30 RGB Gaming Keyboard, 6-Zone RGB Lighting, Water Repellent & Splash-Proof, Mechanical-Like Plunger Switches',
#  'Logitech G PRO X Superlight Wireless Gaming Mouse- White + Logitech G815 LIGHTSYNC RGB Mechanical Gaming Keyboard - Tactile',
#  'Corsair K100 RGB Optical-Mechanical Gaming Keyboard - Corsair OPX RGB Optical-Mechanical Keyswitches - AXON Hyper-Processing Technology for 4X Faster Throughput - 44-Zone RGB LightEdge (Renewed)',
#  'Corsair K63 Wireless Mechanical Gaming Keyboard, backlit Blue LED, Cherry MX Red - Quiet & Linear',
#  'DrunkDeer A75-Mechanical-Keyboard, TKL Gaming Keyboards, Hyper Fast Magnetic-Switch, RGB Wired USB Compact 82 Keys with Knob, Anti-Ghosting Spill-Resistant White',
#  'ROCCAT Vulcan 100 AIMO Mechanical PC Gaming Keyboard, RGB Lighting, Silent, Per Key LED Illumination, Brown Switches, Aluminum Top Plate, Silver',
#  'ASUS ROG Strix Flare II Animate 100% RGB Gaming Keyboard - Hot-swappable, ROG NX Red Linear Switches, Customizable LED Display, PBT Keycaps, Acoustic Dampening Foam, Media Controls, Wrist Rest',
#  'Redragon K552 Mechanical Gaming Keyboard RGB LED Backlit Wired with Anti-Dust Proof Switches for Windows PC (Black, 87 Key Blue Switches)']
