# %% [markdown]
# ## Crawl a page

# %%
import pandas as pd
import re
import datetime
from pandas import DataFrame
import undetected_chromedriver as uc
from time import sleep
from selenium.common import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import ElementNotInteractableException
import urllib.request
import os
from dotenv import load_dotenv

# %%
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920x1080")
driver = uc.Chrome(options=options)

# %%
driver.get('https://www.amazon.com/')

# %% [markdown]
# ### Captcha

# %%
# from PIL import Image
# from pytesseract import pytesseract

# %%
from amazoncaptcha import AmazonCaptcha

# %%
captcha_image = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
    (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-row.a-spacing-large > div > div > div.a-row.a-text-center > img")))
image = captcha_image.get_attribute('src')
filename = datetime.datetime.now()
image_path = 'D:\CrawlDataAmazon\\'
folder_path = os.path.join(os.path.dirname(image_path), "data")
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
urllib.request.urlretrieve(image, os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S"))))
# Out:
# ('D:\\CrawlDataAmazon\\data\\20230713112154.png',
#  <http.client.HTTPMessage at 0x1ed4f4ff5e0>)

# %%
if os.path.exists(folder_path):
    files = os.listdir(folder_path)
    if len(files) > 1:
        files.sort(key=lambda x: os.path.getmtime(os.path.join(folder_path, x)), reverse=True)
        for file in files[1:]:
            file_path = os.path.join(folder_path, file)
            os.remove(file_path)
    print("List images:")
    for file in os.listdir(folder_path):
        print(file)
else:
    print("Folder not found.")
# Out:
# List images:
# 20230713112154.png

# %%
captcha = AmazonCaptcha(os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S"))))
solution = captcha.solve()

# %%
solution
# Out:
# 'KNUGLE'

# %%
# path_to_tesseract = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
# path_to_image = os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S")))
# pytesseract.tesseract_cmd = path_to_tesseract
# img = Image.open(path_to_image)

# #Extract text from image
# text = pytesseract.image_to_string(img)
# print(text)

# %%
captcha = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
    (By.CSS_SELECTOR, "#captchacharacters")))
captcha.send_keys(solution)
sleep(2)

# %%
submit = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
    (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-section.a-spacing-extra-large > div > span > span > button")))
submit.click()

# %% [markdown]
# ### Crawl data

# %%
search_box = driver.find_element(By.ID, 'twotabsearchtextbox')
search_box.clear()

# %%
# input = "gaming keyboard"

# %%
keyword = input('What name do you want to crawl ?')
# Out:
# What name do you want to crawl ?jean

# %%
search_box.send_keys(keyword)
search_button = driver.find_element(By.ID, 'nav-search-submit-button')
search_button.click()
driver.implicitly_wait(5)

# %%
items = WebDriverWait(driver,10).until(EC.presence_of_all_elements_located((By.XPATH, '//div[contains(@class, "s-result-item s-asin")]')))

# %%
items
# Out:
# [<undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_119")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_120")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_121")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_122")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_123")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_124")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_125")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_126")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_127")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_128")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_129")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_130")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_131")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_132")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_133")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_134")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_135")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_136")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_137")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_138")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_139")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_140")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_141")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_142")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_143")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_144")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_145")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_146")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_147")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_148")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_149")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_150")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_151")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_152")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_153")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_154")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_155")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_156")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_157")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_158")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_159")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_160")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_161")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_162")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_163")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_164")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_165")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_166")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_167")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_168")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_169")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_170")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_171")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_172")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_173")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_174")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_175")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_176")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_177")>,
#  <undetected_chromedriver.webelement.WebElement (session="0803c5c89b39f9897a5efe10dbf39d6b", element="486E24261D6B1320B01CB904960551BB_element_178")>]

# %%
product_name = []
product_code = []
product_price = []
product_ratings = []
product_ratings_num = []
product_link = []

# %%
css_name = ['.//span[@class="a-size-base-plus a-color-base a-text-normal"]',
            './/span[@class="a-size-medium a-color-base a-text-normal"]']

# %%
def convert(css_name, item):
    name = ""
    flag = False
    for i in css_name:
        if item.find_element(By.XPATH, i):
            name = item.find_element(By.XPATH, i)
            flag =  True
            break
        else:
            continue
    return name, flag

# %%
for item in items:
    name, flag = convert(css_name, item)
    if flag == False:
        product_name.append(name)
    else:
        product_name.append(name.text)
#                     name = item.find_element(By.XPATH, './/span[@class="a-size-medium a-color-base a-text-normal"]')

    try:
        data_code = item.get_attribute("data-asin")
        product_code.append(data_code)
    except:
        product_code.append("")
    
    # find price
    whole_price = item.find_elements(By.XPATH, './/span[@class="a-price-whole"]')
    fraction_price = item.find_elements(By.XPATH, './/span[@class="a-price-fraction"]')
    
    if whole_price != [] and fraction_price != []:
        price = '.'.join([whole_price[0].text, fraction_price[0].text])
    else:
        price = 0
    product_price.append(price)

    # find ratings box
    ratings_box = item.find_elements(By.XPATH, './/div[@class="a-row a-size-small"]/span')

    # find ratings and ratings_num
    if ratings_box != []:
        ratings = ratings_box[0].get_attribute('aria-label')
        ratings_num = ratings_box[1].get_attribute('aria-label')
    else:
        ratings, ratings_num = 0, 0
    
    product_ratings.append(ratings)
    product_ratings_num.append(str(ratings_num))
    
    # find link
    link = item.find_element(By.XPATH, './/a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]').get_attribute("href")
    product_link.append(link)

# %%
data = pd.DataFrame({'ProductId': product_code,'Name':product_name,
                         'Price': product_price, 'Link':product_link,'Rating':product_ratings,'Rating Count':product_ratings_num,
                         })

# %%
data
# Out:
#      ProductId                                               Name   Price  \
# 0   B07BJL5TRG      Amazon Essentials Men's Slim-Fit Stretch Jean   28.50
# 1   B01LI4IGKC       Lee Men's Extreme Motion Straight Taper Jean   25.37
# 2   B07BJL6XPW      Amazon Essentials Men's Slim-Fit Stretch Jean   28.40
# 3   B074KLF2HC  Wrangler Authentics Men's Regular Fit Comfort ...   30.96
# 4   B0B4R9M45L          Lee Men's Legendary Relaxed Straight Jean   22.78
# 5   B07B6FD3BV  Lee Women's Ultra Lux Comfort with Flex Motion...   30.60
# 6   B00XKXNGT6  Wrangler Authentics Men's Classic 5-Pocket Reg...   29.85
# 7   B073189NR5  WallFlower Women's Luscious Curvy Bootcut Mid-...   26.43
# 8   B074KJ6JH4  Wrangler Authentics Men's Classic 5-Pocket Rel...   31.18
# 9   B0008EOGFS            Lee Men's Regular Fit Straight Leg Jean   36.90
# 10  B000NZXMRU  Gloria Vanderbilt Women's Classic Amanda High ...   15.19
# 11  B07LGVH287                  Rustler Men's Classic Relaxed Fit   14.98
# 12  B089V3FDW6  Lee Women's Plus Size Legendary Mid Rise Strai...   34.90
# 13  B074KHZK7K  Wrangler Authentics Men's Classic 5-Pocket Reg...   31.18
# 14  B09V29JN79  GAP Men's Soft High Stretch Skinny Fit Denim J...   16.00
# 15  B092JMH6FN  Wrangler Women's High Rise True Straight Fit Jean   59.00
# 16  B07T1F917D     Lee Men's Extreme Motion Regular Straight Jean   26.98
# 17  B075MY6M7G  Wrangler Authentics Men’s Comfort Flex Waistba...   27.31
# 18  B07QTVRF4V    Amazon Essentials Women's High-Rise Skinny Jean   25.60
# 19  B0006U68DM  Wrangler Men’s 13MWZ Cowboy Cut Original Fit Jean   28.62
# 20  B07XH53QZ7  Amazon Essentials Men's Athletic-Fit Stretch Jean   31.40
# 45  https://www.amazon.com/GAP-Mens-Gapflex-Jeans-...  4.5 out of 5 stars
# 46  https://www.amazon.com/LEE-Big-Tall-Extreme-St...  4.6 out of 5 stars
# 47  https://www.amazon.com/Democracy-Womens-Soluti...  4.2 out of 5 stars
# 48  https://www.amazon.com/Wrangler-Premium-Denim-...  4.6 out of 5 stars
# 49  https://www.amazon.com/GAP-Taper-Jeans-Black-D...  4.4 out of 5 stars
# 50  https://www.amazon.com/Lee-womens-Rise-Boyfrie...  4.1 out of 5 stars
# 51  https://www.amazon.com/Amazon-Essentials-Skinn...  4.3 out of 5 stars
# 52  https://www.amazon.com/GAP-Womens-Classic-Stra...  4.0 out of 5 stars
# 53  https://www.amazon.com/Mens-Relaxed-Straight-M...  4.4 out of 5 stars
# 54  https://www.amazon.com/Lee-Legendary-Regular-B...  4.5 out of 5 stars
# 55  https://www.amazon.com/Silver-Jeans-Co-Gordie-...  4.5 out of 5 stars
# 56  https://www.amazon.com/LEE-Plus-Size-Regular-B...  4.4 out of 5 stars
# 57  https://www.amazon.com/LEE-Womens-Sculpting-Sk...  4.3 out of 5 stars
# 58  https://www.amazon.com/JEAN-Book-REAPER-Patrio...  4.7 out of 5 stars
# 59  https://www.amazon.com/Amazon-Essentials-Athle...  4.3 out of 5 stars
#
#    Rating Count
# 0        32,434
# 1        24,718
# 2        32,434
# 3        67,618
# 4           667
# 5        10,952
# 6         1,502
# 7        47,897
# 8        50,754
# 9        28,843
# 10       57,481
# 11       12,947
# 12        2,276
# 13       53,962
# 14          184
# 15        1,901
# 16        2,459
# 17       13,283
# 18        6,043
# 19       36,963
# 20       19,882
# 21        8,778
# 22        1,676
# 23        1,515
# 24       14,835
# 25       16,076
# 26       12,927
# 27        2,448
# 28        1,271
# 29          385
# 30          133
# 31            2
# 32       19,103
# 33        8,605
# 34          833
# 35        3,809
# 36            8
# 37           41
# 38           51
# 39          296
# 40       11,036
# 41           85
# 42        3,989
# 43           25
# 44          332
# 45          163
# 46        4,680
# 47          759
# 48        1,154
# 49          213
# 50          198
# 51       13,316
# 52          161
# 53       11,378
# 54          927
# 55        2,549
# 56        5,865
# 57        5,392
# 58          778
# 59       19,882

# %% [markdown]
# ## Crawl Multiple pages

# %%
import pandas as pd
import re
import datetime
from pandas import DataFrame
import undetected_chromedriver as uc
from time import sleep
from selenium.common import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
import urllib.request
import os
from dotenv import load_dotenv
from amazoncaptcha import AmazonCaptcha

# %%
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
driver = uc.Chrome(options=options)
driver.maximize_window()
driver.get('https://www.amazon.com/')

# %% [markdown]
# ### Captcha

# %%
count = 1
while True:
    try:
        captcha_image = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
            (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-row.a-spacing-large > div > div > div.a-row.a-text-center > img")))
        image = captcha_image.get_attribute('src')
        filename = datetime.datetime.now()
        image_path = 'D:\CrawlDataAmazon\\'
        folder_path = os.path.join(os.path.dirname(image_path), "data")
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        urllib.request.urlretrieve(image, os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S"))))
        
        # check folder
        if os.path.exists(folder_path):
            files = os.listdir(folder_path)
            if len(files) > 1:
                files.sort(key=lambda x: os.path.getmtime(os.path.join(folder_path, x)), reverse=True)
                for file in files[1:]:
                    file_path = os.path.join(folder_path, file)
                    os.remove(file_path)
            print("List images:")
            for file in os.listdir(folder_path):
                print(file)
        else:
            print("Folder not found.")
        
        captcha = AmazonCaptcha(os.path.join(folder_path, "{}.png".format(filename.strftime("%Y%m%d%H%M%S"))))
        solution = captcha.solve()
        
        captcha = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
            (By.CSS_SELECTOR, "#captchacharacters")))
        captcha.send_keys(solution)
        sleep(2)
        
        submit = WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
            (By.CSS_SELECTOR, "body > div > div.a-row.a-spacing-double-large > div.a-section > div > div > form > div.a-section.a-spacing-extra-large > div > span > span > button")))
        submit.click()
        count +=1
    except TimeoutException:
        break
# Out:
# List images:
# 20230717150056.png
# List images:
# 20230717150059.png
# List images:
# 20230717150102.png

# %%
search_box = driver.find_element(By.ID, 'twotabsearchtextbox')
search_box.clear()

# %%
# input = "gaming keyboard"

# %%
keyword = input('What name do you want to crawl ?')
# Out:
# What name do you want to crawl ?iphone 14

# %%
search_box.send_keys(keyword)
search_button = driver.find_element(By.ID, 'nav-search-submit-button')
search_button.click()
driver.implicitly_wait(2)

# %%
product_name = []
product_code = []
product_uuid = []
product_price = []
product_ratings = []
product_ratings_num = []
product_link = []

# %%
def convert(css_name, item):
    name = ""
    flag = False
    for i in css_name:
        try:
            name = item.find_element(By.XPATH, i)
            flag = True
            break
        except NoSuchElementException:
            name = ""
    return name, flag

# %% [markdown]
# ### Crawl 4 pages

# %%
css_name = ['.//span[@class="a-size-base-plus a-color-base a-text-normal"]',
            './/span[@class="a-size-medium a-color-base a-text-normal"]']

# %%
for i in range(5):
    try:
        print(f'Page {i + 1}')
        items = WebDriverWait(driver,10).until(EC.presence_of_all_elements_located(
        (By.XPATH, '//div[contains(@class, "s-result-item s-asin")]')))
        for item in items:
            name, flag = convert(css_name, item)
            if flag == False:
                product_name.append(name)
            else:
                product_name.append(name.text)
                
            try:
                uuid = item.get_attribute("data-uuid")
                product_uuid.append(uuid)
            except:
                product_uuid.append("")
                
            try:
                data_code = item.get_attribute("data-asin")
                product_code.append(data_code)
            except:
                product_code.append("")

            # find price
            whole_price = item.find_elements(By.XPATH, './/span[@class="a-price-whole"]')
            fraction_price = item.find_elements(By.XPATH, './/span[@class="a-price-fraction"]')

            if whole_price != [] and fraction_price != []:
                price = '.'.join([whole_price[0].text, fraction_price[0].text])
            else:
                price = 0
            product_price.append(price)

            # find ratings box
            ratings_box = item.find_elements(By.XPATH, './/div[@class="a-row a-size-small"]/span')

            # find ratings and ratings_num
            if ratings_box != []:
                ratings = ratings_box[0].get_attribute('aria-label')
                ratings_num = ratings_box[1].get_attribute('aria-label')
            else:
                ratings, ratings_num = 0, 0

            product_ratings.append(ratings)
            product_ratings_num.append(str(ratings_num))

            # find link
            link = item.find_element(By.XPATH, './/a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]').get_attribute("href")
            product_link.append(link)
        next_page = driver.find_element(By.XPATH, './/a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
        next_page.click()
        sleep(2)
    except ElementNotInteractableException:
        print('Element Not Interactable Exception')
        break
# Out:
# Page 0

# %%
data = pd.DataFrame({'ProductId': product_code,'Name':product_name, 'UUID': product_uuid,
                         'Price': product_price, 'Link':product_link,'Rating':product_ratings,'Rating Count':product_ratings_num,
                         })

# %%
data
# Out:
#      ProductId                                               Name  \
# 0   B08PP5MSVB  Apple iPhone 12, 64GB, Black - Fully Unlocked ...
# 1   B0BLP3ZZXT  SAMSUNG Galaxy S23 Ultra Cell Phone, Factory U...
# 2   B0BGYFDQJX  iPhone 13 Pro Max, 256GB, Sierra Blue - Unlock...
# 3   B09MVZH5RB  SAMSUNG Galaxy S22 Ultra Cell Phone, Factory U...
# 4   B07ZQRL9XY  Apple iPhone 11 Pro, US Version, 256GB, Space ...
# 5   B0B3PSRHHN  Google Pixel 6a - 5G Android Phone - Unlocked ...
# 6   B0BNWPSCGB  OnePlus 11 5G | 16GB RAM+256GB | Dual-SIM | Ti...
# 7   B0BBY6DHJ8  Total by Verizon Samsung Galaxy A03s, 32GB, Bl...
# 8   B0BSLR2L5R  SAMSUNG Galaxy A54 5G A Series Cell Phone, Fac...
# 9   B01N1QKP3D  CR1102GD 32GB Slide Wallet Size Unlocked Mini ...
# 10  B0BCQXXRJJ  Google Pixel 7-5G Android Phone - Unlocked Sma...
# 11  B0B3T9D5T8  SAMSUNG Galaxy Z Flip 4 Cell Phone, Factory Un...
# 12  B09VNW56HZ  Xiaomi Redmi Note 11 Pro+ Plus 5G + 4G Global ...
# 13  B09CLN4LLN  Tracfone Alcatel TCL A3, 32GB, Black - Prepaid...
# 14  B093QPJSKJ  Nokia G10 | Android 11 | Unlocked Smartphone |...
# 15  B0BBY1HQTL  Total by Verizon Samsung Galaxy A13 5G, 64GB, ...
# 16  B0C15NG7V6  iOttie Velox Pro MagSafe Compatible Dash & Win...
# 17  B09GRJ2S8X  Belkin Magnetic Wireless Car Charger - MagSafe...
# 18  B0BZTZPSS5  UBeesize Magnetic Car Mount Holder | 360° Rota...
#
#                                     UUID     Price  \
# 0   6a87d303-2ebd-44d9-8d33-13cb8a4af8f6    384.00
# 1   d8abe317-73c9-4494-80a3-d7d177b62641    999.99
# 2   20ffdc5b-a9f1-4771-8391-4a6d336762c9  1,002.13
# 3   a3a58e09-ce10-4adf-a220-8d657e45cac6    799.99
# 4   9f7bed66-b485-4b91-aa82-19e405ff7059    415.00
# 5   e1527ff2-ea95-4c7a-b22a-66b5313801d9         0
# 6   7103653d-9f8b-446f-81d7-e8d1358d67e4    799.99
# 7   a3d15c39-1bef-4b6c-83a7-bd4c81d39350     49.88
# 8   2c758c46-1e0d-43bb-90b3-0b3f726421dc    449.99
# 9   0a6bfb9b-d8ef-4b1b-93f1-6434202a9b77     23.29
# 10  ffbbe14b-1c39-4451-9fc6-0cf70ff3e8bc    498.44
# 11  7891e475-5b46-484e-89e0-fbf5fda51aca  1,059.99
# 12  53db40b9-b367-4264-bc12-c5012e0cafe4    304.00
# 13  efd90c84-f39d-40b7-a32a-63ea2c216de8     39.88
# 14  7dda05cf-75df-49cc-9430-efa35868c794     99.99
# 15  ba5a970e-e196-473a-961d-4e8059a3beab     79.88
# 16  e939927c-544d-4419-a2f8-84dcf9e78920     74.95
# 17  49606103-b147-4651-a2c8-87c305680124     55.10
# 18  34c30c29-7942-4ab7-a29e-6bbdf6f59cbd     17.47
#
#                                                  Link              Rating  \
# 0   https://www.amazon.com/Apple-iPhone-12-64GB-Bl...  4.2 out of 5 stars
# 1   https://www.amazon.com/SAMSUNG-Factory-Unlocke...  4.6 out of 5 stars
# 2   https://www.amazon.com/iPhone-Pro-256GB-Sierra...  4.1 out of 5 stars
# 3   https://www.amazon.com/SAMSUNG-Smartphone-Unlo...  4.6 out of 5 stars
# 4   https://www.amazon.com/Apple-iPhone-256GB-Unlo...  4.2 out of 5 stars
# 5   https://www.amazon.com/Google-Pixel-6a-Smartph...  4.3 out of 5 stars
# 6   https://www.amazon.com/OnePlus-Dual-SIM-Smartp...  4.4 out of 5 stars
# 7   https://www.amazon.com/Total-Verizon-Samsung-G...  4.0 out of 5 stars
# 8   https://www.amazon.com/SAMSUNG-Factory-Unlocke...  4.1 out of 5 stars
# 9   https://www.amazon.com/SLIDE-Wallet-Unlocked-W...  3.4 out of 5 stars
# 10  https://www.amazon.com/Google-Pixel-7-5G-Andro...  4.3 out of 5 stars
# 11  https://www.amazon.com/SAMSUNG-Unlocked-Smartp...  4.1 out of 5 stars
# 12  https://www.amazon.com/Xiaomi-Version-Unlocked...  4.5 out of 5 stars
# 13  https://www.amazon.com/Tracfone-Alcatel-TCL-32...  4.0 out of 5 stars
# 14  https://www.amazon.com/Nokia-Android-Unlocked-...  3.6 out of 5 stars
# 15  https://www.amazon.com/Total-Verizon-Samsung-G...  3.8 out of 5 stars
# 16  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.2 out of 5 stars
# 17  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.4 out of 5 stars
# 18  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  4.4 out of 5 stars
#
#    Rating Count
# 0         9,552
# 1           193
# 2           822
# 3           599
# 4        18,407
# 5         4,442
# 6           480
# 7           342
# 8           153
# 9            53
# 10        2,486
# 11          189
# 12          724
# 13        1,213
# 14          359
# 15           99
# 16        1,149
# 17        1,936
# 18           61

# %%
data.to_csv('chair.csv')

# %% [markdown]
# ### Crawl end of page

# %%
# count = 1
# while True:
#     try:
#         print(f'Page {count}')
#         items = WebDriverWait(driver,10).until(EC.presence_of_all_elements_located(
#         (By.XPATH, '//div[contains(@class, "s-result-item s-asin")]')))
#         for item in items:
#             try:
#                 name = item.find_element(By.XPATH, './/span[@class="a-size-medium a-color-base a-text-normal"]')
#                 product_name.append(name.text)
#             except:
#                 product_name.append("")

#             try:
#                 data_code = item.get_attribute("data-asin")
#                 product_code.append(data_code)
#             except:
#                 product_code.append("")

#             # find price
#             whole_price = item.find_elements(By.XPATH, './/span[@class="a-price-whole"]')
#             fraction_price = item.find_elements(By.XPATH, './/span[@class="a-price-fraction"]')

#             if whole_price != [] and fraction_price != []:
#                 price = '.'.join([whole_price[0].text, fraction_price[0].text])
#             else:
#                 price = 0
#             product_price.append(price)

#             # find ratings box
#             ratings_box = item.find_elements(By.XPATH, './/div[@class="a-row a-size-small"]/span')

#             # find ratings and ratings_num
#             if ratings_box != []:
#                 ratings = ratings_box[0].get_attribute('aria-label')
#                 ratings_num = ratings_box[1].get_attribute('aria-label')
#             else:
#                 ratings, ratings_num = 0, 0

#             product_ratings.append(ratings)
#             product_ratings_num.append(str(ratings_num))

#             # find link
#             link = item.find_element(By.XPATH, './/a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]').get_attribute("href")
#             product_link.append(link)
#         next_page = driver.find_element(By.XPATH, './/a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
#         count +=1
#         next_page.click()
#         sleep(2)
#     except ElementNotInteractableException:
#         print('Element Not Interactable Exception')
#         break
